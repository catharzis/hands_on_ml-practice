# %% [markdown]
# # Обучение и визуализация
#
# Универскальный и мощный алгоритм, подходящий как для регрессии так и для классификации.

# %%
import numpy as np
import os
import pandas as pd

# %%
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier

iris = load_iris()
X = iris.data[:, 2:]
y = iris.target

tree_clf = DecisionTreeClassifier(max_depth=2, random_state=42)
tree_clf.fit(X, y)
# Out:
# DecisionTreeClassifier(max_depth=2, random_state=42)

# %%
pd.DataFrame(iris['data'])
# Out:
#        0    1    2    3
# 0    5.1  3.5  1.4  0.2
# 1    4.9  3.0  1.4  0.2
# 2    4.7  3.2  1.3  0.2
# 3    4.6  3.1  1.5  0.2
# 4    5.0  3.6  1.4  0.2
# ..   ...  ...  ...  ...
# 145  6.7  3.0  5.2  2.3
# 146  6.3  2.5  5.0  1.9
# 147  6.5  3.0  5.2  2.0
# 148  6.2  3.4  5.4  2.3
# 149  5.9  3.0  5.1  1.8
#
# [150 rows x 4 columns]

# %%
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "decision_trees"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)
os.makedirs(IMAGES_PATH, exist_ok=True)

# %%
IMAGES_PATH
# Out:
# './images/decision_trees'

# %%
from sklearn.tree import export_graphviz

def image_path(fig_id):
    return os.path.join(IMAGES_PATH, fig_id)

export_graphviz(
        tree_clf,
        out_file=image_path("iris_tree.dot"),
        feature_names=iris.feature_names[2:],
        class_names=iris.target_names,
        rounded=True,
        filled=True
    )

# %%
iris.feature_names[2:]
# Out:
# ['petal length (cm)', 'petal width (cm)']

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
# !ls -l *.png
# Out:
# -rw-r--r-- 1 root root 55868 Jan 20 09:13 iris_tree.png

# %%
! dot -Tpng './images/decision_trees/iris_tree.dot' -o 'iris_tree.png'

# %% [markdown]
# # Оценивание вероятности классов

# %%
tree_clf.predict_proba([[5, 1.5]])
# Out:
# array([[0.        , 0.90740741, 0.09259259]])

# %%
tree_clf.predict([[5, 1.5]])
# Out:
# array([1])

# %% [markdown]
# # Регрессия

# %%
# Quadratic training set + noise
np.random.seed(42)
m = 200
X = np.random.rand(m, 1)
y = 4 * (X - 0.5) ** 2
y = y + np.random.randn(m, 1) / 10

# %%
from sklearn.tree import DecisionTreeRegressor

tree_reg = DecisionTreeRegressor(max_depth=2, random_state=42)
tree_reg.fit(X, y)
# Out:
# DecisionTreeRegressor(max_depth=2, random_state=42)

# %%
tree_reg1 = DecisionTreeRegressor(random_state=42, max_depth=2)
tree_reg2 = DecisionTreeRegressor(random_state=42, max_depth=3)
tree_reg1.fit(X, y)
tree_reg2.fit(X, y)
# Out:
# DecisionTreeRegressor(max_depth=3, random_state=42)

# %%
tree_reg1.predict([[0.5]])
# Out:
# array([0.11063973])

# %% [markdown]
# # Классы sklearn для деревьев:

# %% [markdown]
# Регрессия:
#
# DecisionTreeRegressor
#
# * max_deapth
# * min_samples_leaf

# %% [markdown]
# Класификация:
#
# DecisionTreeClassifier
#
# * max_depth
# * min_samples_split
# * min_samples_leaf
# * max_leaf_nodes
# * max_features
